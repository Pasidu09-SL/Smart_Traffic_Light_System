# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt # for mac

# %%
model = YOLO('yolov8x.pt')

# %%
img = cv2.imread('041.jpg')

# %%
result = model(img)
# Out:
# 0: 448x640 6 persons, 9 cars, 1 truck, 471.8ms
# Speed: 2.4ms preprocess, 471.8ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)

# %%
print(result)
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
# obb: None
# orig_img: array([[[157, 152, 173],
#         [160, 159, 179],
#         [168, 169, 189],
#         ...,
#         [102, 100,  99],
#         [102, 100, 106],
#         [107, 124, 120]],
#
#        [[164, 159, 180],
#         [155, 154, 174],
#         [160, 161, 181],
#         ...,
#         [ 71,  80,  77],
#         [ 99, 102, 107],
#         [115, 129, 125]],
#
#        [[164, 159, 180],
#         [152, 151, 171],
#         [166, 167, 187],
#         ...,
#         [ 69,  92,  87],
#         [ 90,  99, 103],
#         [129, 136, 133]],
#
#        ...,
#
#        [[ 71,  60,  92],
#         [ 76,  65,  98],
#         [ 72,  61,  94],
#         ...,
#         [178, 180, 181],
#         [179, 181, 182],
#         [176, 178, 179]],
#
#        [[173, 174, 178],
#         [181, 181, 187],
#         [179, 179, 185],
#         ...,
#         [178, 180, 181],
#         [181, 183, 184],
#         [177, 179, 180]],
#
#        [[182, 187, 185],
#         [189, 194, 192],
#         [185, 190, 188],
#         ...,
#         [177, 179, 180],
#         [180, 182, 183],
#         [177, 179, 180]]], dtype=uint8)
# orig_shape: (400, 600)
# path: 'image0.jpg'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 2.355834000354662, 'inference': 471.8484999998509, 'postprocess': 0.9132920004049083}]

# %%
print(result[0].boxes)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 2., 7., 2., 2., 2., 2., 2., 0., 0., 2., 0., 2., 0., 0., 0.])
# conf: tensor([0.9508, 0.9366, 0.9048, 0.8995, 0.7720, 0.7308, 0.7045, 0.6537, 0.6100, 0.6004, 0.4991, 0.4398, 0.3950, 0.3407, 0.3363, 0.3106])
# data: tensor([[1.1920e-01, 2.0133e+02, 2.0293e+02, 3.9231e+02, 9.5085e-01, 2.0000e+00],
#         [3.9062e+02, 1.7209e+02, 5.5082e+02, 2.9167e+02, 9.3664e-01, 2.0000e+00],
#         [2.5076e+02, 9.1563e+01, 3.9530e+02, 2.7631e+02, 9.0481e-01, 7.0000e+00],
#         [1.4313e+02, 1.6044e+02, 2.5878e+02, 2.8781e+02, 8.9949e-01, 2.0000e+00],
#         [3.8000e+02, 1.4949e+02, 4.3466e+02, 2.2304e+02, 7.7198e-01, 2.0000e+00],
#         [5.1260e+02, 1.5286e+02, 5.9588e+02, 2.5821e+02, 7.3082e-01, 2.0000e+00],
#         [4.8256e+02, 1.4648e+02, 5.3136e+02, 1.7503e+02, 7.0453e-01, 2.0000e+00],
#         [0.0000e+00, 1.3364e+02, 1.4486e+02, 2.0686e+02, 6.5369e-01, 2.0000e+00],
#         [4.6755e+02, 1.4917e+02, 4.8871e+02, 1.7269e+02, 6.0997e-01, 0.0000e+00],
#         [4.3422e+02, 1.4890e+02, 4.5932e+02, 1.7421e+02, 6.0035e-01, 0.0000e+00],
#         [5.1260e+02, 1.5286e+02, 5.9588e+02, 2.5821e+02],
#         [4.8256e+02, 1.4648e+02, 5.3136e+02, 1.7503e+02],
#         [0.0000e+00, 1.3364e+02, 1.4486e+02, 2.0686e+02],
#         [4.6755e+02, 1.4917e+02, 4.8871e+02, 1.7269e+02],
#         [4.3422e+02, 1.4890e+02, 4.5932e+02, 1.7421e+02],
#         [1.8371e+02, 1.4744e+02, 2.5715e+02, 1.8668e+02],
#         [4.8355e+02, 1.5559e+02, 5.0666e+02, 1.7420e+02],
#         [1.4479e-01, 1.8545e+02, 2.5346e+01, 2.2308e+02],
#         [1.6112e+02, 1.7885e+02, 1.8545e+02, 2.0348e+02],
#         [3.0987e+02, 1.5419e+02, 3.4465e+02, 1.8316e+02],
#         [2.6732e+02, 1.5429e+02, 3.0498e+02, 1.7891e+02]])
# xyxyn: tensor([[1.9867e-04, 5.0332e-01, 3.3821e-01, 9.8079e-01],
#         [6.5103e-01, 4.3023e-01, 9.1804e-01, 7.2918e-01],
#         [4.1793e-01, 2.2891e-01, 6.5884e-01, 6.9077e-01],
#         [2.3855e-01, 4.0110e-01, 4.3130e-01, 7.1952e-01],
#         [6.3334e-01, 3.7372e-01, 7.2444e-01, 5.5759e-01],
#         [8.5434e-01, 3.8216e-01, 9.9313e-01, 6.4552e-01],
#         [8.0427e-01, 3.6620e-01, 8.8560e-01, 4.3757e-01],
#         [0.0000e+00, 3.3410e-01, 2.4144e-01, 5.1716e-01],
#         [7.7926e-01, 3.7293e-01, 8.1452e-01, 4.3173e-01],
#         [7.2370e-01, 3.7224e-01, 7.6553e-01, 4.3552e-01],
#         [3.0619e-01, 3.6859e-01, 4.2859e-01, 4.6670e-01],
#         [8.0591e-01, 3.8898e-01, 8.4443e-01, 4.3551e-01],
#         [2.4131e-04, 4.6361e-01, 4.2243e-02, 5.5770e-01],
#         [2.6853e-01, 4.4713e-01, 3.0908e-01, 5.0870e-01],
#         [5.1645e-01, 3.8547e-01, 5.7441e-01, 4.5789e-01],
#         [4.4554e-01, 3.8572e-01, 5.0830e-01, 4.4727e-01]])

# %%
objects = []
for box in (result[0].boxes):
    cords = (box.xyxy[0].tolist())
    cords = [round(x)for x in cords]
    x1,y1,x2,y2 = cords
    top_cord = x1,y1
    bot_cord = x2,y2
    print(top_cord,bot_cord)
    objects.append((top_cord,bot_cord))
# Out:
#   Cell In[9], line 3
#     print (box.cls[0]item())
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
#for top_cord,bot_cord in objects:
 #   cv2.rectangle(img,top_cord,bot_cord,color=(0,0,255),thickness=1)
  #  cv2.imshow('Image',img)
   # cv2.waitKey(0)
    #cv2.destroyAllWindows()

for top_cord, bot_cord in objects:
    cv2.rectangle(img, top_cord, bot_cord, color=(255, 0, 0), thickness=1)

# Display image in Jupyter
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()
